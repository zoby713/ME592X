# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
fname = 'original.png'
image = Image.open(fname).convert("L")
arr= np.asarray(image)
plt.imshow(arr, cmap='gray')
plt.show()
#convert picture to grayscale

# %%
plt.hist(arr.ravel(),256,[0,256]);plt.show()
#plot histogram

# %% [markdown]
# Part 2 of the assignment

# %%
import pandas as pd

# %%
df1 = pandas.read_csv("C:\Users\Zoby\OneDrive\Graduate School\Iowa State University 2019 Spring\ME 592X\Assignments\Assignment 1\energydata_complete.csv")
print(df1)
# Out:
#   File "<ipython-input-17-d90e381fdbb5>", line 1
#     df1 = pandas.read_csv("C:\Users\Zoby\OneDrive\Graduate School\Iowa State University 2019 Spring\ME 592X\Assignments\Assignment 1\energydata_complete.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
